# %%
import random

# %%
#Three input
choices = ["Rock","Paper","Scissors"]

player = False
cpu_score = 0
player_score = 0
# condition for game 
while True:
    # give input as a player
    player = input("Rock,Paper or Scissors?").capitalize()
    # random selection though Computer
    computer = random.choice(choices)
    
    if player == computer:
        print("Tie!")
    elif player == "Rock":
        if computer == "Paper":
            print("You Lose!", computer, "covers", player)
            cpu_score+=1
        else:
            print('You Win!', player, "smashes", computer)
            player_score+=1
    elif player == "Paper":
        if computer == "Scissors":
            print("You lose!", computer, "cut", player)
            cpu_score+=1
        else:
            print("You win!", player, "covers", computer)
            player_score+=1
    elif player == "Scissors":
        if computer == "Rock":
            print("You lose...", computer, "smashes", player)
            cpu_score+=1
        else:
            print("You win!", player, "cut", computer)
            player_score+=1
    elif player=='End':
        print("************************************************")
        if cpu_score == player_score:
            print("Match Tie with score {}.".format(player_score))
        elif cpu_score > player_score:
            print("CPU Match won by score {} vs {} ".format(cpu_score,player_score))
        else:
            print("Player Match won by score {1} vs {0} ".format(cpu_score,player_score))
            
        break
# Out:
# Rock,Paper or Scissors?paper
# Tie!
# Rock,Paper or Scissors?rock
# Tie!
# Rock,Paper or Scissors?paper
# You win! Paper covers Rock
# Rock,Paper or Scissors?rock
# Tie!
# Rock,Paper or Scissors?rock
# You Lose! Paper covers Rock
# Rock,Paper or Scissors?scissor
# Rock,Paper or Scissors?Scissors
# You lose... Rock smashes Scissors
# Rock,Paper or Scissors?Scissors
# Tie!
# Rock,Paper or Scissors?Scissors
# You lose... Rock smashes Scissors
# Rock,Paper or Scissors?Scissors
# Tie!
# Rock,Paper or Scissors?Scissors
# You win! Scissors cut Paper
# Rock,Paper or Scissors?Scissors
# You lose... Rock smashes Scissors
# Rock,Paper or Scissors?Scissors
# You lose... Rock smashes Scissors
# Rock,Paper or Scissors?
# Rock,Paper or Scissors?Scissors
# You win! Scissors cut Paper
# Rock,Paper or Scissors?Scissors
# Tie!
# Rock,Paper or Scissors?Scissors
# You win! Scissors cut Paper
# Rock,Paper or Scissors?Scissors
# Tie!
# Rock,Paper or Scissors?Scissors
# Tie!
# ...
